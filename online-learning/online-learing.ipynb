# %%
import pandas as pd
from scipy.io import arff

path = 'datasets/INSECTS-abrupt_balanced_norm.arff'
data = arff.loadarff(path)
dataset = pd.DataFrame(data)

dataset.head()
# Out:
#                                                0      \
# 0  [0.507066, 0.153333, 0.226092, 0.302447, 0.007...
# 1                                               Att1
#
#                                                1      \
# 0  [0.281661, 0.355953, 0.253196, 0.340335, 0.415...
# 1                                               Att2
#
#                                                2      \
# 0  [0.19375, 0.257782, 0.183339, 0.247017, 0.3021...
# 1                                               Att3
#
#                                                3      \
# 0  [0.514782, 0.154867, 0.016903, 0.226084, 0.297...
# 1                                               Att4
#
#                                                4      \
# 0  [0.774337, 0.012549, 0.105751, 0.033302, 0.017...
# 1                                               Att5
#
#                                                5      \
# 0  [0.290048, 0.376655, 0.265364, 0.002345, 0.349...
# ...
